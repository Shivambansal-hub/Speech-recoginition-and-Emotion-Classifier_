# %%
# !pip install --upgrade scikit-learn imbalanced-learn
# Out:
# Requirement already satisfied: scikit-learn in /opt/anaconda3/lib/python3.11/site-packages (1.2.2)
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.0-cp311-cp311-macosx_12_0_arm64.whl.metadata (31 kB)
# Requirement already satisfied: imbalanced-learn in /opt/anaconda3/lib/python3.11/site-packages (0.11.0)
# Collecting imbalanced-learn
#   Downloading imbalanced_learn-0.13.0-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: numpy>=1.22.0 in /opt/anaconda3/lib/python3.11/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.8.0 in /opt/anaconda3/lib/python3.11/site-packages (from scikit-learn) (1.11.4)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting sklearn-compat<1,>=0.1 (from imbalanced-learn)
#   Downloading sklearn_compat-0.1.3-py3-none-any.whl.metadata (18 kB)
# Collecting scikit-learn
#   Downloading scikit_learn-1.6.1-cp311-cp311-macosx_12_0_arm64.whl.metadata (31 kB)
# Downloading imbalanced_learn-0.13.0-py3-none-any.whl (238 kB)
# Downloading joblib-1.5.1-py3-none-any.whl (307 kB)
# Downloading sklearn_compat-0.1.3-py3-none-any.whl (18 kB)
# Downloading scikit_learn-1.6.1-cp311-cp311-macosx_12_0_arm64.whl (11.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 3.3 MB/s eta 0:00:00a 0:00:01
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn, sklearn-compat, imbalanced-learn
#   Attempting uninstall: threadpoolctl
#     Found existing installation: threadpoolctl 2.2.0
#     Uninstalling threadpoolctl-2.2.0:
#       Successfully uninstalled threadpoolctl-2.2.00m 0/5 [threadpoolctl]
#   Attempting uninstall: joblib━━━━━━━━━━━━━━ 0/5 [threadpoolctl]
#     Found existing installation: joblib 1.1.1 0/5 [threadpoolctl]
#     Uninstalling joblib-1.1.1:━━━━━━━━━━━━━━ 0/5 [threadpoolctl]
#       Successfully uninstalled joblib-1.1.1━ 0/5 [threadpoolctl]
#   Attempting uninstall: scikit-learn━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/5 [joblib]
#     Found existing installation: scikit-learn 1.2.2━━━━━━━━━━━ 1/5 [joblib]
#     Uninstalling scikit-learn-1.2.2:━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/5 [joblib]
#       Successfully uninstalled scikit-learn-1.2.2━━━━━━━━━━━━━ 1/5 [joblib]
#   Attempting uninstall: imbalanced-learn90m━━━━━━━━━━━━━━━━━━━━━━━ 2/5 [scikit-learn]
#     Found existing installation: imbalanced-learn 0.11.0━━━━━━ 2/5 [scikit-learn]
#     Uninstalling imbalanced-learn-0.11.0:━━━━━━━━━━━━━━━━━━━━━ 2/5 [scikit-learn]
#       Successfully uninstalled imbalanced-learn-0.11.0━━━━━━━━ 2/5 [scikit-learn]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [imbalanced-learn]kit-learn]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.2.0 requires joblib~=1.1.0, but you have joblib 1.5.1 which is incompatible.
# Successfully installed imbalanced-learn-0.13.0 joblib-1.5.1 scikit-learn-1.6.1 sklearn-compat-0.1.3 threadpoolctl-3.6.0

# %%
import pandas as pd
import numpy as np
import librosa
import os
import matplotlib.pyplot as plt
import seaborn as sns
from imblearn.over_sampling import SMOTE
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers.schedules import ExponentialDecay
from tensorflow.keras.layers import Input, Conv1D, BatchNormalization, Flatten, Activation, LSTM, Bidirectional, Add, SpatialDropout1D, GlobalAveragePooling1D, Dense, Dropout
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers

print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available: 0

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, BatchNormalization, Dropout
from tensorflow.keras.layers import Bidirectional, LSTM, Dense
from tensorflow.keras import regularizers
import tensorflow as tf
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# %%
data_dir = "Final_Dataset/"

# %%
max_len = 300
feature_dim = 45
SAMPLE_RATE = 16000

sequences = []
labels = []

def load_and_preprocess(file_path, sr=SAMPLE_RATE):
    y, _ = librosa.load(file_path, sr=sr)

    # 1️⃣ Trim leading/trailing silence
    y, _ = librosa.effects.trim(y, top_db=30)

    # 2️⃣ Normalize to [-1.0, 1.0]
    y = y / np.max(np.abs(y)) if np.max(np.abs(y)) > 0 else y

    return y

def extract_features(y, sr=SAMPLE_RATE, max_len=300):
    # MFCC + delta + delta-delta
    mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13)
    delta1 = librosa.feature.delta(mfcc)
    delta2 = librosa.feature.delta(mfcc, order=2)

    # Spectral features
    centroid = librosa.feature.spectral_centroid(y=y, sr=sr)
    bandwidth = librosa.feature.spectral_bandwidth(y=y, sr=sr)
    rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr)
    rms = librosa.feature.rms(y=y)
    zcr = librosa.feature.zero_crossing_rate(y=y)

    # Pitch using YIN
    try:
        f0 = librosa.yin(y=y, sr=sr, fmin=librosa.note_to_hz('C2'), fmax=librosa.note_to_hz('C7'))
        f0 = f0.reshape(1, -1)
    except:
        f0 = np.zeros((1, mfcc.shape[1]))

    # All features should match MFCC's time dimension (T)
    T = mfcc.shape[1]

    def resize(feat):
        return feat[:, :T] if feat.shape[1] >= T else np.pad(feat, ((0, 0), (0, T - feat.shape[1])), mode='constant')

    # Stack all features vertically
    all_features = np.vstack([
        mfcc,              # (13, T)
        delta1,            # (13, T)
        delta2,            # (13, T)
        resize(centroid),  # (1, T)
        resize(bandwidth), # (1, T)
        resize(rolloff),   # (1, T)
        resize(rms),       # (1, T)
        resize(zcr),       # (1, T)
        resize(f0)         # (1, T)
    ])  # → (45, T)

    # Transpose to shape: (T, 45)
    features = all_features.T  # → (T, 45)

    # Pad or truncate to (300, 45)
    if features.shape[0] < max_len:
        pad_width = max_len - features.shape[0]
        features = np.pad(features, ((0, pad_width), (0, 0)), mode='constant')
    else:
        features = features[:max_len, :]

    return features  # Final shape: (300, 45)

# %%
for file in os.listdir(data_dir):
    if not file.endswith('.wav'):
        continue

    # Emotion code is 8th character (index 6 if zero-indexed, or 7 if you were correct)
    code = file[7]  # Make sure this matches your filename pattern

    if   code == '1':
        label = 'neutral'
    elif code == '2':
        label = 'calm'
    elif code == '3':
        label = 'happy'
    elif code == '4':
        label = 'sad'
    elif code == '5':
        label = 'angry'
    elif code == '6':
        label = 'fearful'
    elif code == '7':
        label = 'disgust'
    elif code == '8':
        label = 'surprised'
    else:
        continue  # unknown label, skip

    file_path = os.path.join(data_dir, file)

    y = load_and_preprocess(file_path, sr=SAMPLE_RATE)
    feature_vector = extract_features(y, sr=SAMPLE_RATE)

    sequences.append(feature_vector)
    labels.append(label)

# %%
X = pad_sequences(
    sequences,
    maxlen=max_len,
    dtype='float32',
    padding='post',
    truncating='post'
)

# %%
X.shape
# Out:
# (2070, 300, 45)

# %%
le = LabelEncoder()
y_int = le.fit_transform(labels)
y = to_categorical(y_int)

# %%
print("Total samples:", len(labels))
print("X shape:", X.shape)   # → (n_samples, max_len, 33)
print("y shape:", y.shape)   # → (n_samples,)
# Out:
# Total samples: 2070
# X shape: (2070, 300, 45)
# y shape: (2070, 8)

# %%
for idx, emo in enumerate(le.classes_):
    print(f"  {idx} → {emo}")
# Out:
#   0 → angry
#   1 → calm
#   2 → disgust
#   3 → fearful
#   4 → happy
#   5 → neutral
#   6 → sad
#   7 → surprised

# %%
X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# %%
num_features = X.shape[2]  # e.g., 36
scaler = StandardScaler()
X_train_2d = X_train.reshape(-1, num_features)
scaler.fit(X_train_2d)
# Out:
# StandardScaler()

# %%
X_train_scaled = scaler.transform(X_train.reshape(-1, num_features)).reshape(X_train.shape)
X_val_scaled   = scaler.transform(X_val.reshape(-1, num_features)).reshape(X_val.shape)

# %%
X_train = X_train_scaled
X_val = X_val_scaled

# %%
y_val.shape
# Out:
# (414, 8)

# %%
import joblib
joblib.dump(scaler, "scaler.pkl")
# Out:
# ['scaler.pkl']

# %%
# suppose X.shape == (n_samples, timesteps, feat_dim)
n_samples, timesteps, feat_dim = X_train.shape

# 1) flatten
X_flat = X_train.reshape(n_samples, timesteps * feat_dim)

# 2) resample
smote = SMOTE(random_state=42)
X_flat_res, y_res = smote.fit_resample(X_flat, y_train)

# 3) reshape back to sequences
n_resampled = X_flat_res.shape[0]
X_res = X_flat_res.reshape(n_resampled, timesteps, feat_dim)

print("Resampled shapes:", X_res.shape, y_res.shape)
# Out:
# Resampled shapes: (2408, 300, 45) (2408, 8)

# %%
y_orig = np.argmax(y_train, axis=1)
y_resampled = np.argmax(y_res, axis=1)

# Get sorted list of classes
classes = np.unique(np.concatenate((y_orig, y_resampled)))

# Count occurrences
counts_before = [(y_orig == cls).sum() for cls in classes]
counts_after  = [(y_resampled == cls).sum() for cls in classes]

# Plot side by side
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

axes[0].bar(classes, counts_before, color='skyblue')
axes[0].set_title('Class Distribution Before SMOTE')
axes[0].set_xlabel('Class Label')
axes[0].set_ylabel('Count')

axes[1].bar(classes, counts_after, color='salmon')
axes[1].set_title('Class Distribution After SMOTE')
axes[1].set_xlabel('Class Label')
axes[1].set_ylabel('Count')

plt.tight_layout()
plt.show()

# %%
def add_noise(X, noise_level=0.01):
    noise = np.random.normal(0, noise_level, X.shape)
    return X + noise

def random_time_scaling(X, scale_range=(0.9, 1.1)):
    scaled = []
    for seq in X:
        factor = np.random.uniform(*scale_range)
        scaled.append(seq * factor)
    return np.array(scaled)

def time_mask(X, max_mask_size=5):
    X_masked = X.copy()
    for i in range(X.shape[0]):
        t = np.random.randint(0, X.shape[1] - max_mask_size)
        X_masked[i, t:t+max_mask_size, :] = 0
    return X_masked

X_augmented_noise = add_noise(X_res)
X_augmented_scaled = random_time_scaling(X_res)
X_augmented_masked = time_mask(X_res)

X_aug = np.concatenate([X_res, X_augmented_noise, X_augmented_scaled, X_augmented_masked], axis=0)
y_aug = np.concatenate([y_res] * 4, axis=0)

print("Augmented shape:", X_aug.shape, y_aug.shape)
# Out:
# Augmented shape: (9632, 300, 45) (9632, 8)

# %%
num_classes = y.shape[1]  # one-hot → shape (num_samples, num_classes)
input_shape = (300, 45)   # from your feature extractor

model = Sequential()

# 1️⃣ First Conv Block
model.add(Conv1D(128, kernel_size=5, activation='relu', padding='same',
                 kernel_regularizer=regularizers.l2(0.001),
                 input_shape=input_shape))
model.add(BatchNormalization())
model.add(MaxPooling1D(pool_size=2))
model.add(Dropout(0.4))  # Increased dropout

# 2️⃣ Conv Block 2
model.add(Conv1D(256, kernel_size=5, activation='relu', padding='same',
                 kernel_regularizer=regularizers.l2(0.001)))
model.add(BatchNormalization())
model.add(MaxPooling1D(pool_size=2))
model.add(Dropout(0.4))

# 3️⃣ BiLSTM Layer
model.add(Bidirectional(LSTM(128)))
model.add(Dropout(0.5))  # Increased dropout

# 4️⃣ Dense Layer
model.add(Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(Dropout(0.5))

# 5️⃣ Output Layer
model.add(Dense(num_classes, activation='softmax'))

# 6️⃣ Compile with label smoothing
model.compile(
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    optimizer='adam',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_12 (Conv1D)              │ (None, 300, 128)       │        28,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_12          │ (None, 300, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_2 (MaxPooling1D)  │ (None, 150, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 150, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_13 (Conv1D)              │ (None, 150, 256)       │       164,096 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_13          │ (None, 150, 256)       │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_3 (MaxPooling1D)  │ (None, 75, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 75, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 256)            │       394,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 8)              │         1,032 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 622,728 (2.38 MB)
#  Trainable params: 621,960 (2.37 MB)
#  Non-trainable params: 768 (3.00 KB)

# %%
model.compile(
    optimizer='adam',
    loss=CategoricalCrossentropy(label_smoothing=0.1),  # ✅ smoothing
    metrics=['accuracy']
)

# %%
checkpoint = ModelCheckpoint(
    filepath='best_model.keras',
    monitor='val_loss',
    save_best_only=True,
    verbose=1
)

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=15,
    restore_best_weights=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-6,
    verbose=1
)
history = model.fit(
    X_aug, y_aug,
    validation_data=(X_val, y_val),
    epochs=200,
    batch_size=32,
    callbacks=[checkpoint, early_stop, reduce_lr],
    verbose=1
)
# Out:
# Epoch 1/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.1672 - loss: 3.3541
# Epoch 1: val_loss improved from inf to 2.09924, saving model to best_model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 40s 126ms/step - accuracy: 0.1674 - loss: 3.3524 - val_accuracy: 0.3333 - val_loss: 2.0992 - learning_rate: 0.0010
# Epoch 2/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.4272 - loss: 2.0034
# Epoch 2: val_loss improved from 2.09924 to 1.72765, saving model to best_model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 41s 137ms/step - accuracy: 0.4273 - loss: 2.0031 - val_accuracy: 0.5121 - val_loss: 1.7276 - learning_rate: 0.0010
# Epoch 3/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.5961 - loss: 1.6489
# Epoch 3: val_loss improved from 1.72765 to 1.52268, saving model to best_model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 40s 133ms/step - accuracy: 0.5962 - loss: 1.6488 - val_accuracy: 0.6522 - val_loss: 1.5227 - learning_rate: 0.0010
# Epoch 4/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.6953 - loss: 1.4675
# Epoch 4: val_loss improved from 1.52268 to 1.47371, saving model to best_model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 39s 131ms/step - accuracy: 0.6953 - loss: 1.4674 - val_accuracy: 0.6715 - val_loss: 1.4737 - learning_rate: 0.0010
# Epoch 5/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.7581 - loss: 1.3540
# Epoch 5: val_loss improved from 1.47371 to 1.44901, saving model to best_model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 39s 130ms/step - accuracy: 0.7581 - loss: 1.3539 - val_accuracy: 0.7029 - val_loss: 1.4490 - learning_rate: 0.0010
# Epoch 6/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.8257 - loss: 1.2459
# Epoch 6: val_loss did not improve from 1.44901
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 41s 135ms/step - accuracy: 0.8257 - loss: 1.2458 - val_accuracy: 0.6860 - val_loss: 1.4816 - learning_rate: 0.0010
# Epoch 7/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8534 - loss: 1.1781
# Epoch 7: val_loss improved from 1.44901 to 1.44386, saving model to best_model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 41s 135ms/step - accuracy: 0.8534 - loss: 1.1780 - val_accuracy: 0.7222 - val_loss: 1.4439 - learning_rate: 0.0010
# Epoch 8/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.8815 - loss: 1.1341
# Epoch 8: val_loss improved from 1.44386 to 1.40510, saving model to best_model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 38s 126ms/step - accuracy: 0.8815 - loss: 1.1340 - val_accuracy: 0.7464 - val_loss: 1.4051 - learning_rate: 0.0010
# Epoch 9/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.8870 - loss: 1.1172
# Epoch 9: val_loss improved from 1.40510 to 1.35538, saving model to best_model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 39s 130ms/step - accuracy: 0.8870 - loss: 1.1173 - val_accuracy: 0.7729 - val_loss: 1.3554 - learning_rate: 0.0010
# Epoch 10/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.8999 - loss: 1.0970
# Epoch 10: val_loss did not improve from 1.35538
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 39s 131ms/step - accuracy: 0.8999 - loss: 1.0970 - val_accuracy: 0.7633 - val_loss: 1.4201 - learning_rate: 0.0010
# Epoch 11/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.8883 - loss: 1.1165
# Epoch 11: val_loss did not improve from 1.35538
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 40s 133ms/step - accuracy: 0.8883 - loss: 1.1164 - val_accuracy: 0.7512 - val_loss: 1.4890 - learning_rate: 0.0010
# Epoch 12/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.9175 - loss: 1.0721
# Epoch 12: val_loss did not improve from 1.35538
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 41s 136ms/step - accuracy: 0.9175 - loss: 1.0721 - val_accuracy: 0.7560 - val_loss: 1.3994 - learning_rate: 0.0010
# Epoch 13/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9241 - loss: 1.0492
# Epoch 13: val_loss did not improve from 1.35538
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 41s 136ms/step - accuracy: 0.9240 - loss: 1.0493 - val_accuracy: 0.7729 - val_loss: 1.4026 - learning_rate: 0.0010
# Epoch 14/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9175 - loss: 1.0620
# Epoch 14: val_loss did not improve from 1.35538
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 41s 135ms/step - accuracy: 0.9175 - loss: 1.0620 - val_accuracy: 0.7705 - val_loss: 1.4307 - learning_rate: 0.0010
# Epoch 15/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9486 - loss: 0.9889
# Epoch 15: val_loss did not improve from 1.35538
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 40s 134ms/step - accuracy: 0.9486 - loss: 0.9888 - val_accuracy: 0.7899 - val_loss: 1.3931 - learning_rate: 5.0000e-04
# Epoch 16/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9638 - loss: 0.9350
# Epoch 16: val_loss did not improve from 1.35538
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 41s 135ms/step - accuracy: 0.9638 - loss: 0.9350 - val_accuracy: 0.7681 - val_loss: 1.3563 - learning_rate: 5.0000e-04
# Epoch 17/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9708 - loss: 0.9068
# Epoch 17: val_loss improved from 1.35538 to 1.30127, saving model to best_model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 41s 135ms/step - accuracy: 0.9708 - loss: 0.9068 - val_accuracy: 0.7947 - val_loss: 1.3013 - learning_rate: 5.0000e-04
# Epoch 18/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.9670 - loss: 0.8841
# Epoch 18: val_loss improved from 1.30127 to 1.26323, saving model to best_model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 42s 139ms/step - accuracy: 0.9670 - loss: 0.8840 - val_accuracy: 0.8019 - val_loss: 1.2632 - learning_rate: 5.0000e-04
# Epoch 19/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.9682 - loss: 0.8759
# Epoch 19: val_loss did not improve from 1.26323
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 41s 137ms/step - accuracy: 0.9682 - loss: 0.8759 - val_accuracy: 0.8019 - val_loss: 1.2797 - learning_rate: 5.0000e-04
# Epoch 20/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.9734 - loss: 0.8553
# Epoch 20: val_loss improved from 1.26323 to 1.22009, saving model to best_model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 42s 139ms/step - accuracy: 0.9734 - loss: 0.8553 - val_accuracy: 0.8092 - val_loss: 1.2201 - learning_rate: 5.0000e-04
# Epoch 21/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.9686 - loss: 0.8600
# Epoch 21: val_loss did not improve from 1.22009
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 42s 139ms/step - accuracy: 0.9686 - loss: 0.8600 - val_accuracy: 0.8213 - val_loss: 1.2967 - learning_rate: 5.0000e-04
# Epoch 22/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9725 - loss: 0.8451
# Epoch 22: val_loss did not improve from 1.22009
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 43s 143ms/step - accuracy: 0.9725 - loss: 0.8451 - val_accuracy: 0.8261 - val_loss: 1.2566 - learning_rate: 5.0000e-04
# Epoch 23/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9723 - loss: 0.8413
# Epoch 23: val_loss did not improve from 1.22009
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 43s 143ms/step - accuracy: 0.9723 - loss: 0.8413 - val_accuracy: 0.7874 - val_loss: 1.3289 - learning_rate: 5.0000e-04
# Epoch 24/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.9777 - loss: 0.8235
# Epoch 24: val_loss improved from 1.22009 to 1.21395, saving model to best_model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 42s 140ms/step - accuracy: 0.9777 - loss: 0.8235 - val_accuracy: 0.8116 - val_loss: 1.2140 - learning_rate: 5.0000e-04
# Epoch 25/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9763 - loss: 0.8243
# Epoch 25: val_loss did not improve from 1.21395
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 40s 133ms/step - accuracy: 0.9763 - loss: 0.8243 - val_accuracy: 0.7778 - val_loss: 1.2816 - learning_rate: 5.0000e-04
# Epoch 26/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.9675 - loss: 0.8447
# Epoch 26: val_loss improved from 1.21395 to 1.20321, saving model to best_model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 38s 127ms/step - accuracy: 0.9675 - loss: 0.8447 - val_accuracy: 0.8043 - val_loss: 1.2032 - learning_rate: 5.0000e-04
# Epoch 27/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.9777 - loss: 0.8092
# Epoch 27: val_loss did not improve from 1.20321
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 40s 131ms/step - accuracy: 0.9777 - loss: 0.8092 - val_accuracy: 0.7705 - val_loss: 1.3138 - learning_rate: 5.0000e-04
# Epoch 28/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.9712 - loss: 0.8234
# Epoch 28: val_loss did not improve from 1.20321
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 39s 131ms/step - accuracy: 0.9712 - loss: 0.8234 - val_accuracy: 0.8019 - val_loss: 1.2776 - learning_rate: 5.0000e-04
# Epoch 29/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9756 - loss: 0.8134
# Epoch 29: val_loss did not improve from 1.20321
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 40s 134ms/step - accuracy: 0.9756 - loss: 0.8134 - val_accuracy: 0.7464 - val_loss: 1.4189 - learning_rate: 5.0000e-04
# Epoch 30/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.9752 - loss: 0.8117
# Epoch 30: val_loss did not improve from 1.20321
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 41s 137ms/step - accuracy: 0.9752 - loss: 0.8117 - val_accuracy: 0.7778 - val_loss: 1.3173 - learning_rate: 5.0000e-04
# Epoch 31/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9707 - loss: 0.8172
# Epoch 31: val_loss did not improve from 1.20321
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 41s 136ms/step - accuracy: 0.9707 - loss: 0.8172 - val_accuracy: 0.8092 - val_loss: 1.2256 - learning_rate: 5.0000e-04
# Epoch 32/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9843 - loss: 0.7864
# Epoch 32: val_loss did not improve from 1.20321
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 41s 134ms/step - accuracy: 0.9843 - loss: 0.7864 - val_accuracy: 0.8164 - val_loss: 1.2405 - learning_rate: 2.5000e-04
# Epoch 33/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.9866 - loss: 0.7628
# Epoch 33: val_loss did not improve from 1.20321
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 42s 138ms/step - accuracy: 0.9866 - loss: 0.7628 - val_accuracy: 0.8164 - val_loss: 1.2256 - learning_rate: 2.5000e-04
# Epoch 34/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.9892 - loss: 0.7511
# Epoch 34: val_loss improved from 1.20321 to 1.17688, saving model to best_model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 42s 139ms/step - accuracy: 0.9892 - loss: 0.7511 - val_accuracy: 0.8261 - val_loss: 1.1769 - learning_rate: 2.5000e-04
# Epoch 35/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9914 - loss: 0.7396
# Epoch 35: val_loss improved from 1.17688 to 1.17566, saving model to best_model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 42s 141ms/step - accuracy: 0.9914 - loss: 0.7396 - val_accuracy: 0.8237 - val_loss: 1.1757 - learning_rate: 2.5000e-04
# Epoch 36/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.9908 - loss: 0.7346
# Epoch 36: val_loss did not improve from 1.17566
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 42s 140ms/step - accuracy: 0.9908 - loss: 0.7346 - val_accuracy: 0.8188 - val_loss: 1.1901 - learning_rate: 2.5000e-04
# Epoch 37/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.9927 - loss: 0.7233
# Epoch 37: val_loss did not improve from 1.17566
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 41s 138ms/step - accuracy: 0.9927 - loss: 0.7233 - val_accuracy: 0.8237 - val_loss: 1.1847 - learning_rate: 2.5000e-04
# Epoch 38/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.9886 - loss: 0.7253
# Epoch 38: val_loss improved from 1.17566 to 1.14786, saving model to best_model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 42s 139ms/step - accuracy: 0.9886 - loss: 0.7253 - val_accuracy: 0.8357 - val_loss: 1.1479 - learning_rate: 2.5000e-04
# Epoch 39/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9884 - loss: 0.7207
# Epoch 39: val_loss did not improve from 1.14786
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 43s 142ms/step - accuracy: 0.9884 - loss: 0.7207 - val_accuracy: 0.8261 - val_loss: 1.1701 - learning_rate: 2.5000e-04
# Epoch 40/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9901 - loss: 0.7161
# Epoch 40: val_loss improved from 1.14786 to 1.14696, saving model to best_model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 42s 140ms/step - accuracy: 0.9901 - loss: 0.7161 - val_accuracy: 0.8237 - val_loss: 1.1470 - learning_rate: 2.5000e-04
# Epoch 41/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9907 - loss: 0.7090
# Epoch 41: val_loss did not improve from 1.14696
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 43s 141ms/step - accuracy: 0.9907 - loss: 0.7090 - val_accuracy: 0.8092 - val_loss: 1.1977 - learning_rate: 2.5000e-04
# Epoch 42/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.9919 - loss: 0.6995
# Epoch 42: val_loss did not improve from 1.14696
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 42s 139ms/step - accuracy: 0.9919 - loss: 0.6995 - val_accuracy: 0.8213 - val_loss: 1.1708 - learning_rate: 2.5000e-04
# Epoch 43/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.9914 - loss: 0.6984
# Epoch 43: val_loss did not improve from 1.14696
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 41s 137ms/step - accuracy: 0.9914 - loss: 0.6984 - val_accuracy: 0.8164 - val_loss: 1.1610 - learning_rate: 2.5000e-04
# Epoch 44/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.9896 - loss: 0.6994
# Epoch 44: val_loss did not improve from 1.14696
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 42s 139ms/step - accuracy: 0.9896 - loss: 0.6994 - val_accuracy: 0.8188 - val_loss: 1.1549 - learning_rate: 2.5000e-04
# Epoch 45/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9927 - loss: 0.6933
# Epoch 45: val_loss improved from 1.14696 to 1.12860, saving model to best_model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 42s 141ms/step - accuracy: 0.9927 - loss: 0.6933 - val_accuracy: 0.8213 - val_loss: 1.1286 - learning_rate: 2.5000e-04
# Epoch 46/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.9877 - loss: 0.6943
# Epoch 46: val_loss improved from 1.12860 to 1.10026, saving model to best_model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 42s 140ms/step - accuracy: 0.9877 - loss: 0.6943 - val_accuracy: 0.8188 - val_loss: 1.1003 - learning_rate: 2.5000e-04
# Epoch 47/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9925 - loss: 0.6826
# Epoch 47: val_loss did not improve from 1.10026
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 43s 142ms/step - accuracy: 0.9925 - loss: 0.6826 - val_accuracy: 0.8116 - val_loss: 1.1974 - learning_rate: 2.5000e-04
# Epoch 48/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9904 - loss: 0.6891
# Epoch 48: val_loss improved from 1.10026 to 1.07529, saving model to best_model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 43s 142ms/step - accuracy: 0.9904 - loss: 0.6891 - val_accuracy: 0.8430 - val_loss: 1.0753 - learning_rate: 2.5000e-04
# Epoch 49/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9935 - loss: 0.6771
# Epoch 49: val_loss improved from 1.07529 to 1.07258, saving model to best_model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 44s 147ms/step - accuracy: 0.9935 - loss: 0.6771 - val_accuracy: 0.8454 - val_loss: 1.0726 - learning_rate: 2.5000e-04
# Epoch 50/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9913 - loss: 0.6809
# Epoch 50: val_loss did not improve from 1.07258
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 43s 144ms/step - accuracy: 0.9913 - loss: 0.6809 - val_accuracy: 0.8285 - val_loss: 1.0921 - learning_rate: 2.5000e-04
# Epoch 51/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9927 - loss: 0.6742
# Epoch 51: val_loss did not improve from 1.07258
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 43s 141ms/step - accuracy: 0.9927 - loss: 0.6742 - val_accuracy: 0.8043 - val_loss: 1.1858 - learning_rate: 2.5000e-04
# Epoch 52/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.9888 - loss: 0.6793
# Epoch 52: val_loss did not improve from 1.07258
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 42s 139ms/step - accuracy: 0.9888 - loss: 0.6793 - val_accuracy: 0.8116 - val_loss: 1.1857 - learning_rate: 2.5000e-04
# Epoch 53/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.9910 - loss: 0.6769
# Epoch 53: val_loss did not improve from 1.07258
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 48s 161ms/step - accuracy: 0.9910 - loss: 0.6768 - val_accuracy: 0.8454 - val_loss: 1.0832 - learning_rate: 2.5000e-04
# Epoch 54/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9919 - loss: 0.6740
# Epoch 54: val_loss did not improve from 1.07258
#
# Epoch 54: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 45s 150ms/step - accuracy: 0.9919 - loss: 0.6740 - val_accuracy: 0.8213 - val_loss: 1.1359 - learning_rate: 2.5000e-04
# Epoch 55/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9900 - loss: 0.6731
# Epoch 55: val_loss improved from 1.07258 to 1.07051, saving model to best_model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9900 - loss: 0.6731 - val_accuracy: 0.8406 - val_loss: 1.0705 - learning_rate: 1.2500e-04
# Epoch 56/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9925 - loss: 0.6688
# Epoch 56: val_loss did not improve from 1.07051
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 44s 145ms/step - accuracy: 0.9925 - loss: 0.6688 - val_accuracy: 0.8285 - val_loss: 1.1061 - learning_rate: 1.2500e-04
# Epoch 57/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9961 - loss: 0.6546
# Epoch 57: val_loss did not improve from 1.07051
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 43s 143ms/step - accuracy: 0.9961 - loss: 0.6546 - val_accuracy: 0.8213 - val_loss: 1.1126 - learning_rate: 1.2500e-04
# Epoch 58/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9942 - loss: 0.6535
# Epoch 58: val_loss improved from 1.07051 to 1.06450, saving model to best_model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 45s 149ms/step - accuracy: 0.9942 - loss: 0.6535 - val_accuracy: 0.8309 - val_loss: 1.0645 - learning_rate: 1.2500e-04
# Epoch 59/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9968 - loss: 0.6470
# Epoch 59: val_loss improved from 1.06450 to 1.05743, saving model to best_model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 44s 147ms/step - accuracy: 0.9968 - loss: 0.6470 - val_accuracy: 0.8382 - val_loss: 1.0574 - learning_rate: 1.2500e-04
# Epoch 60/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.9948 - loss: 0.6482
# Epoch 60: val_loss did not improve from 1.05743
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 61s 203ms/step - accuracy: 0.9948 - loss: 0.6482 - val_accuracy: 0.8333 - val_loss: 1.0682 - learning_rate: 1.2500e-04
# Epoch 61/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9961 - loss: 0.6426
# Epoch 61: val_loss did not improve from 1.05743
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 54s 180ms/step - accuracy: 0.9961 - loss: 0.6426 - val_accuracy: 0.8261 - val_loss: 1.1209 - learning_rate: 1.2500e-04
# Epoch 62/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9963 - loss: 0.6425
# Epoch 62: val_loss did not improve from 1.05743
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 52s 171ms/step - accuracy: 0.9963 - loss: 0.6425 - val_accuracy: 0.8261 - val_loss: 1.0850 - learning_rate: 1.2500e-04
# Epoch 63/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9968 - loss: 0.6382
# Epoch 63: val_loss did not improve from 1.05743
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 44s 146ms/step - accuracy: 0.9968 - loss: 0.6382 - val_accuracy: 0.8333 - val_loss: 1.0872 - learning_rate: 1.2500e-04
# Epoch 64/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9935 - loss: 0.6422
# Epoch 64: val_loss improved from 1.05743 to 1.04502, saving model to best_model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 44s 145ms/step - accuracy: 0.9935 - loss: 0.6422 - val_accuracy: 0.8357 - val_loss: 1.0450 - learning_rate: 1.2500e-04
# Epoch 65/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9976 - loss: 0.6304
# Epoch 65: val_loss did not improve from 1.04502
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 57s 190ms/step - accuracy: 0.9976 - loss: 0.6304 - val_accuracy: 0.8285 - val_loss: 1.0989 - learning_rate: 1.2500e-04
# Epoch 66/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9966 - loss: 0.6302
# Epoch 66: val_loss did not improve from 1.04502
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 64s 212ms/step - accuracy: 0.9966 - loss: 0.6302 - val_accuracy: 0.8188 - val_loss: 1.1123 - learning_rate: 1.2500e-04
# Epoch 67/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.9944 - loss: 0.6334
# Epoch 67: val_loss did not improve from 1.04502
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 51s 171ms/step - accuracy: 0.9944 - loss: 0.6334 - val_accuracy: 0.8213 - val_loss: 1.1032 - learning_rate: 1.2500e-04
# Epoch 68/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9942 - loss: 0.6346
# Epoch 68: val_loss improved from 1.04502 to 1.03061, saving model to best_model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 43s 144ms/step - accuracy: 0.9942 - loss: 0.6346 - val_accuracy: 0.8478 - val_loss: 1.0306 - learning_rate: 1.2500e-04
# Epoch 69/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9967 - loss: 0.6268
# Epoch 69: val_loss did not improve from 1.03061
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 43s 142ms/step - accuracy: 0.9967 - loss: 0.6268 - val_accuracy: 0.8430 - val_loss: 1.0380 - learning_rate: 1.2500e-04
# Epoch 70/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9979 - loss: 0.6217
# Epoch 70: val_loss did not improve from 1.03061
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 43s 142ms/step - accuracy: 0.9979 - loss: 0.6217 - val_accuracy: 0.8309 - val_loss: 1.0838 - learning_rate: 1.2500e-04
# Epoch 71/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9958 - loss: 0.6230
# Epoch 71: val_loss did not improve from 1.03061
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 42s 140ms/step - accuracy: 0.9958 - loss: 0.6230 - val_accuracy: 0.8333 - val_loss: 1.0741 - learning_rate: 1.2500e-04
# Epoch 72/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.9978 - loss: 0.6189
# Epoch 72: val_loss did not improve from 1.03061
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 42s 139ms/step - accuracy: 0.9978 - loss: 0.6189 - val_accuracy: 0.8261 - val_loss: 1.0947 - learning_rate: 1.2500e-04
# Epoch 73/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9962 - loss: 0.6206
# Epoch 73: val_loss did not improve from 1.03061
#
# Epoch 73: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 42s 141ms/step - accuracy: 0.9962 - loss: 0.6206 - val_accuracy: 0.8285 - val_loss: 1.0880 - learning_rate: 1.2500e-04
# Epoch 74/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9969 - loss: 0.6161
# Epoch 74: val_loss did not improve from 1.03061
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 45s 148ms/step - accuracy: 0.9969 - loss: 0.6162 - val_accuracy: 0.8261 - val_loss: 1.0673 - learning_rate: 6.2500e-05
# Epoch 75/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9975 - loss: 0.6129
# Epoch 75: val_loss improved from 1.03061 to 1.02206, saving model to best_model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 44s 146ms/step - accuracy: 0.9975 - loss: 0.6129 - val_accuracy: 0.8454 - val_loss: 1.0221 - learning_rate: 6.2500e-05
# Epoch 76/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9984 - loss: 0.6125
# Epoch 76: val_loss did not improve from 1.02206
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 44s 148ms/step - accuracy: 0.9984 - loss: 0.6125 - val_accuracy: 0.8140 - val_loss: 1.0714 - learning_rate: 6.2500e-05
# Epoch 77/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9975 - loss: 0.6112
# Epoch 77: val_loss did not improve from 1.02206
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 43s 142ms/step - accuracy: 0.9975 - loss: 0.6112 - val_accuracy: 0.8309 - val_loss: 1.0512 - learning_rate: 6.2500e-05
# Epoch 78/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9977 - loss: 0.6096
# Epoch 78: val_loss improved from 1.02206 to 1.01988, saving model to best_model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 43s 144ms/step - accuracy: 0.9977 - loss: 0.6096 - val_accuracy: 0.8599 - val_loss: 1.0199 - learning_rate: 6.2500e-05
# Epoch 79/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.9974 - loss: 0.6081
# Epoch 79: val_loss improved from 1.01988 to 1.00446, saving model to best_model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 108s 360ms/step - accuracy: 0.9974 - loss: 0.6081 - val_accuracy: 0.8502 - val_loss: 1.0045 - learning_rate: 6.2500e-05
# Epoch 80/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.9983 - loss: 0.6061
# Epoch 80: val_loss did not improve from 1.00446
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 76s 250ms/step - accuracy: 0.9983 - loss: 0.6061 - val_accuracy: 0.8237 - val_loss: 1.0963 - learning_rate: 6.2500e-05
# Epoch 81/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9975 - loss: 0.6068
# Epoch 81: val_loss did not improve from 1.00446
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 55s 182ms/step - accuracy: 0.9975 - loss: 0.6068 - val_accuracy: 0.8382 - val_loss: 1.0534 - learning_rate: 6.2500e-05
# Epoch 82/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.9983 - loss: 0.6048
# Epoch 82: val_loss did not improve from 1.00446
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 49s 164ms/step - accuracy: 0.9983 - loss: 0.6048 - val_accuracy: 0.8478 - val_loss: 1.0060 - learning_rate: 6.2500e-05
# Epoch 83/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9976 - loss: 0.6063
# Epoch 83: val_loss did not improve from 1.00446
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 47s 156ms/step - accuracy: 0.9976 - loss: 0.6063 - val_accuracy: 0.8454 - val_loss: 1.0438 - learning_rate: 6.2500e-05
# Epoch 84/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9982 - loss: 0.6019
# Epoch 84: val_loss did not improve from 1.00446
#
# Epoch 84: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 45s 148ms/step - accuracy: 0.9982 - loss: 0.6019 - val_accuracy: 0.8430 - val_loss: 1.0521 - learning_rate: 6.2500e-05
# Epoch 85/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9992 - loss: 0.6002
# Epoch 85: val_loss did not improve from 1.00446
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 43s 144ms/step - accuracy: 0.9992 - loss: 0.6002 - val_accuracy: 0.8309 - val_loss: 1.0934 - learning_rate: 3.1250e-05
# Epoch 86/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9981 - loss: 0.6004
# Epoch 86: val_loss did not improve from 1.00446
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 45s 149ms/step - accuracy: 0.9981 - loss: 0.6004 - val_accuracy: 0.8285 - val_loss: 1.0822 - learning_rate: 3.1250e-05
# Epoch 87/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9983 - loss: 0.5998
# Epoch 87: val_loss did not improve from 1.00446
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 43s 144ms/step - accuracy: 0.9983 - loss: 0.5998 - val_accuracy: 0.8382 - val_loss: 1.0502 - learning_rate: 3.1250e-05
# Epoch 88/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9976 - loss: 0.6001
# Epoch 88: val_loss did not improve from 1.00446
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 43s 144ms/step - accuracy: 0.9976 - loss: 0.6001 - val_accuracy: 0.8430 - val_loss: 1.0505 - learning_rate: 3.1250e-05
# Epoch 89/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9974 - loss: 0.5994
# Epoch 89: val_loss did not improve from 1.00446
#
# Epoch 89: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 44s 145ms/step - accuracy: 0.9974 - loss: 0.5994 - val_accuracy: 0.8357 - val_loss: 1.0522 - learning_rate: 3.1250e-05
# Epoch 90/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9991 - loss: 0.5979
# Epoch 90: val_loss did not improve from 1.00446
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 42s 141ms/step - accuracy: 0.9991 - loss: 0.5979 - val_accuracy: 0.8357 - val_loss: 1.0435 - learning_rate: 1.5625e-05
# Epoch 91/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9988 - loss: 0.5966
# Epoch 91: val_loss did not improve from 1.00446
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 43s 143ms/step - accuracy: 0.9988 - loss: 0.5966 - val_accuracy: 0.8357 - val_loss: 1.0507 - learning_rate: 1.5625e-05
# Epoch 92/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9985 - loss: 0.5970
# Epoch 92: val_loss did not improve from 1.00446
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 43s 144ms/step - accuracy: 0.9985 - loss: 0.5970 - val_accuracy: 0.8382 - val_loss: 1.0406 - learning_rate: 1.5625e-05
# Epoch 93/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9997 - loss: 0.5951
# Epoch 93: val_loss did not improve from 1.00446
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 43s 144ms/step - accuracy: 0.9997 - loss: 0.5951 - val_accuracy: 0.8357 - val_loss: 1.0460 - learning_rate: 1.5625e-05
# Epoch 94/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9986 - loss: 0.5953
# Epoch 94: val_loss did not improve from 1.00446
#
# Epoch 94: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 43s 144ms/step - accuracy: 0.9986 - loss: 0.5953 - val_accuracy: 0.8382 - val_loss: 1.0283 - learning_rate: 1.5625e-05
# Epoch 94: early stopping
# Restoring model weights from the end of the best epoch: 79.

# %%
# Pull out the values for each metric
acc      = history.history.get('accuracy', history.history.get('acc'))
val_acc  = history.history.get('val_accuracy', history.history.get('val_acc'))
loss     = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(loss) + 1)

plt.figure(figsize=(12, 5))

# 1) Accuracy plot
plt.subplot(1, 2, 1)
plt.plot(epochs, acc,      marker='o', label='Train Accuracy')
plt.plot(epochs, val_acc,  marker='o', label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# 2) Loss plot
plt.subplot(1, 2, 2)
plt.plot(epochs, loss,      marker='o', label='Train Loss')
plt.plot(epochs, val_loss,  marker='o', label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
y_val.shape
# Out:
# (414, 8)

# %%
# Predictions → Probabilities → Class Indices
y_val_pred_probs = model.predict(X_val)
y_val_pred = np.argmax(y_val_pred_probs, axis=1)

# Convert one-hot labels to class indices
y_val_true = np.argmax(y_val, axis=1)

# Accuracy Scores
val_acc = accuracy_score(y_val_true, y_val_pred)

print(f"✅ Validation Accuracy: {val_acc:.4f}")
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# ✅ Validation Accuracy: 0.8502

# %%
print("y_val shape:", y_val.shape)
print("y_val_pred shape:", y_val_pred.shape)

y_val_pred
# Out:
# y_val shape: (414, 8)
# y_val_pred shape: (414,)
# array([0, 3, 2, 0, 0, 0, 4, 1, 7, 2, 4, 4, 6, 1, 5, 3, 7, 6, 0, 0, 4, 2,
#        5, 1, 0, 4, 0, 4, 2, 2, 4, 6, 3, 0, 2, 0, 5, 6, 1, 0, 7, 1, 7, 0,
#        1, 0, 4, 4, 3, 1, 1, 2, 6, 3, 6, 2, 0, 4, 0, 0, 1, 0, 4, 1, 1, 1,
#        1, 0, 3, 5, 7, 1, 3, 2, 5, 1, 6, 0, 0, 4, 6, 1, 5, 1, 1, 4, 0, 5,
#        1, 0, 1, 1, 4, 4, 7, 2, 3, 7, 0, 5, 6, 4, 4, 2, 4, 0, 0, 5, 5, 7,
#        1, 1, 3, 4, 0, 4, 4, 4, 5, 0, 3, 7, 4, 2, 3, 0, 4, 7, 1, 5, 2, 5,
#        1, 1, 6, 7, 0, 4, 1, 2, 1, 1, 1, 1, 6, 6, 2, 4, 1, 0, 3, 0, 3, 0,
#        4, 7, 6, 0, 1, 4, 3, 4, 2, 1, 3, 4, 4, 5, 3, 4, 1, 0, 0, 0, 5, 7,
#        0, 4, 3, 4, 6, 6, 1, 1, 4, 5, 0, 6, 3, 4, 4, 6, 1, 2, 1, 0, 7, 4,
#        3, 1, 0, 5, 6, 3, 0, 2, 6, 4, 0, 5, 1, 5, 7, 5, 4, 1, 6, 1, 0, 3,
#        3, 5, 2, 7, 0, 0, 1, 2, 5, 5, 1, 4, 2, 5, 4, 3, 1, 6, 2, 1, 0, 5,
#        2, 7, 2, 4, 7, 0, 7, 4, 1, 1, 0, 1, 5, 4, 2, 6, 0, 0, 4, 1, 4, 2,
#        1, 5, 7, 6, 7, 6, 1, 1, 1, 6, 5, 1, 5, 2, 6, 1, 4, 1, 2, 2, 1, 2,
#        5, 0, 1, 0, 2, 4, 7, 2, 6, 4, 0, 4, 4, 6, 2, 1, 2, 4, 6, 4, 7, 2,
#        6, 3, 1, 5, 3, 7, 6, 7, 7, 0, 6, 5, 3, 6, 4, 1, 6, 1, 6, 2, 6, 6,
#        0, 7, 0, 4, 3, 2, 1, 6, 7, 7, 1, 2, 3, 4, 6, 6, 4, 3, 5, 4, 4, 6,
#        1, 1, 1, 0, 2, 1, 1, 7, 7, 3, 0, 0, 7, 7, 7, 7, 1, 4, 0, 1, 1, 4,
#        5, 0, 1, 7, 3, 5, 6, 0, 6, 5, 4, 4, 5, 5, 6, 3, 6, 3, 3, 2, 1, 4,
#        1, 5, 7, 4, 0, 6, 7, 7, 7, 5, 1, 2, 7, 2, 7, 4, 7, 0])

# %%
print(y_val_true.shape)
y_val_true
# Out:
# (414,)
# array([0, 3, 2, 0, 0, 0, 4, 1, 7, 0, 4, 7, 6, 1, 5, 3, 7, 6, 6, 0, 4, 2,
#        5, 1, 0, 4, 0, 4, 2, 2, 4, 6, 6, 0, 7, 0, 5, 5, 1, 0, 7, 1, 7, 0,
#        1, 0, 4, 4, 3, 1, 1, 2, 6, 3, 6, 2, 0, 4, 0, 0, 1, 0, 4, 6, 1, 1,
#        1, 0, 3, 5, 6, 1, 3, 2, 1, 1, 6, 0, 0, 6, 6, 1, 5, 1, 1, 4, 0, 5,
#        1, 0, 1, 1, 4, 4, 7, 2, 6, 7, 0, 1, 6, 7, 4, 2, 4, 0, 0, 5, 5, 0,
#        1, 6, 3, 4, 0, 4, 4, 7, 1, 3, 3, 7, 4, 2, 4, 0, 4, 7, 1, 4, 2, 5,
#        1, 1, 6, 4, 0, 4, 1, 2, 1, 1, 1, 1, 6, 6, 2, 4, 4, 0, 3, 0, 3, 0,
#        4, 7, 7, 0, 1, 1, 3, 4, 2, 1, 3, 4, 4, 5, 3, 4, 1, 0, 0, 2, 5, 7,
#        0, 4, 3, 6, 3, 3, 1, 1, 4, 5, 0, 6, 3, 4, 4, 6, 1, 2, 1, 0, 7, 4,
#        3, 1, 0, 5, 6, 3, 0, 2, 6, 1, 0, 5, 1, 6, 7, 5, 4, 1, 6, 1, 0, 3,
#        3, 5, 2, 7, 0, 3, 1, 2, 5, 5, 5, 4, 2, 5, 4, 3, 6, 6, 2, 1, 0, 5,
#        2, 7, 2, 4, 7, 0, 7, 4, 1, 1, 0, 1, 5, 4, 2, 6, 0, 0, 4, 1, 4, 2,
#        1, 5, 7, 6, 4, 6, 1, 1, 1, 6, 1, 1, 6, 6, 6, 1, 4, 1, 2, 2, 5, 2,
#        5, 0, 1, 0, 2, 4, 7, 2, 6, 4, 0, 4, 4, 6, 2, 1, 2, 4, 6, 4, 7, 6,
#        3, 3, 1, 5, 3, 7, 6, 7, 7, 3, 3, 1, 3, 6, 3, 6, 6, 1, 6, 2, 5, 6,
#        0, 7, 0, 4, 6, 2, 1, 6, 7, 3, 1, 2, 4, 4, 6, 6, 4, 3, 5, 6, 4, 6,
#        1, 1, 6, 4, 2, 1, 1, 7, 7, 3, 0, 0, 7, 3, 2, 7, 1, 4, 0, 5, 1, 4,
#        5, 0, 6, 7, 3, 5, 6, 3, 3, 5, 4, 4, 5, 5, 6, 3, 6, 3, 3, 2, 1, 4,
#        1, 5, 3, 4, 0, 6, 3, 7, 7, 5, 1, 2, 7, 6, 7, 4, 3, 0])

# %%
print("Unique labels in y_val_true:", np.unique(y_val_true))
print("Unique labels in y_val_pred:", np.unique(y_val_pred))
# Out:
# Unique labels in y_val_true: [0 1 2 3 4 5 6 7]
# Unique labels in y_val_pred: [0 1 2 3 4 5 6 7]

# %%
emotion_labels = ['Neutral', 'Calm', 'Happy', 'Sad', 'Angry', 'Fearful', 'Disgust', 'Surprised']

# 2️⃣ Compute confusion matrix
cm = confusion_matrix(y_val_true, y_val_pred)

# 3️⃣ Normalize (optional)
cm_norm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# %%
class_names = list(le.classes_)
num_classes = len(class_names)
tick_marks = np.arange(num_classes)

# 4) Plot all 4 matrices
fig, axes = plt.subplots(2, figsize=(16, 12))

# Confusion Matrix - Validation (Counts)
axes[0].imshow(cm_val, interpolation='nearest', cmap=plt.cm.Blues)
axes[0].set_title("Validation Confusion Matrix (Counts)")
axes[0].set_xticks(tick_marks)
axes[0].set_yticks(tick_marks)
axes[0].set_xticklabels(class_names, rotation=45, ha='right')
axes[0].set_yticklabels(class_names)
axes[0].set_xlabel('Predicted Label')
axes[0].set_ylabel('True Label')
for i in range(num_classes):
    for j in range(num_classes):
        axes[0].text(j, i, format(cm_val[i, j], 'd'),
                        ha="center", va="center",
                        color="white" if cm_val[i, j] > cm_val.max()/2 else "black")

# Confusion Matrix - Validation (Normalized)
axes[1].imshow(cm_val_norm, interpolation='nearest', cmap=plt.cm.Blues)
axes[1].set_title("Validation Confusion Matrix (Normalized)")
axes[1].set_xticks(tick_marks)
axes[1].set_yticks(tick_marks)
axes[1].set_xticklabels(class_names, rotation=45, ha='right')
axes[1].set_yticklabels(class_names)
axes[1].set_xlabel('Predicted Label')
axes[1].set_ylabel('True Label')
for i in range(num_classes):
    for j in range(num_classes):
        axes[1].text(j, i, f"{cm_val_norm[i, j]:.2f}",
                        ha="center", va="center",
                        color="white" if cm_val_norm[i, j] > 0.5 else "black")

# axes[1, 0].axis('off')
# axes[1, 1].axis('off')
plt.tight_layout()
plt.show()

# %%
import numpy as np
from sklearn.metrics import f1_score

def evaluate_f1_score(model, X_test, y_test, average='weighted'):
    y_prob = model.predict(X_test)
    y_pred = np.argmax(y_prob, axis=1)       # Convert from one-hot/prob to class index
    y_true = np.argmax(y_test, axis=1) if y_test.ndim > 1 else y_test  # Handle one-hot

    return f1_score(y_true, y_pred, average=average)

# %%
f1 = evaluate_f1_score(model, X_val, y_val)
print(f"F1 Score: {f1:.4f}")
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# F1 Score: 0.8468
